# %% [markdown]
# # QuatPlot demo
# Interactive 3D plots with quaternion rotation (via ganja.js, no gimbal lock), rendered in an iframe.
#
# Requirements: `quatplot.py` in the same directory (or on `sys.path`), numpy, and a Jupyter environment. The ganja.js CDN is used when reachable; otherwise a built-in quaternion fallback kicks in automatically.

# %%
import numpy as np
import quatplot as qp

# %% [markdown]
# ## Surface plot
# MATLAB-style *peaks* function on a 41×41 grid. Drag to rotate, wheel to zoom, shift-drag to pan. Try **Top view** with isometric projection for a 2D-heatmap look.

# %%
x = np.linspace(-3, 3, 41)
y = np.linspace(-3, 3, 41)
X, Y = np.meshgrid(x, y)
Z = (3*(1 - X)**2 * np.exp(-X**2 - (Y + 1)**2)
     - 10*(X/5 - X**3 - Y**5) * np.exp(-X**2 - Y**2)
     - 1/3 * np.exp(-(X + 1)**2 - Y**2))

qp.plot(qp.Surface(x, y, Z), height=520)
# Out:
# <div style="resize:both;overflow:hidden;width:100%;height:520px;min-width:280px;min-height:180px;padding:0 0 12px 0;box-sizing:border-box;border:1px solid #8884;border-radius:4px;"><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
# &lt;meta charset=&quot;utf-8&quot;&gt;
# &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1&quot;&gt;
# &lt;title&gt;QuatPlot&lt;/title&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/ganja.js&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
#   :root{
#     --bg:#f5f6f8; --panel:#ffffff; --ink:#1c2430; --muted:#68737f;
#     --edge:#d8dde3; --accent:#2563b0; --grid:#c9cfd6; --cube:#b6bdc6;
#     --tip-bg:#1c2430; --tip-ink:#f5f6f8;
#   }
#   [data-theme=&quot;dark&quot;]{
#     --bg:#14181d; --panel:#1d232a; --ink:#e8ecf1; --muted:#93a0ad;
#     --edge:#313a44; --accent:#5aa2e8; --grid:#3a444f; --cube:#4a5560;
#     --tip-bg:#e8ecf1; --tip-ink:#14181d;
#   }
# ...

# %% [markdown]
# ## Scatter plot
# Three gaussian clusters plus a helix, colored by a value array `v`. Hover a marker for its coordinates; toggle the **Color bar** to see the value scale.

# %%
rng = np.random.default_rng(42)
centers = np.array([[-1.8, -1.8, -4], [2, 1.5, 2], [-1, 2.2, 6]])
cl = np.concatenate([c + rng.normal(scale=[0.5, 0.5, 1.2], size=(35, 3)) for c in centers])
cval = np.repeat([0.0, 1/3, 2/3], 35)

t = np.linspace(0, 4*np.pi, 45)
hx, hy, hz = 2.6*np.cos(t), 2.6*np.sin(t), np.linspace(-6, 6, 45)
hv = 0.6 + 0.4*np.linspace(0, 1, 45)

px = np.concatenate([cl[:, 0], hx]); py = np.concatenate([cl[:, 1], hy])
pz = np.concatenate([cl[:, 2], hz]); pv = np.concatenate([cval, hv])

qp.plot(qp.Scatter3(px, py, pz, v=pv), colorbar=True, cmap='Plasma', height=520)
# Out:
# <div style="resize:both;overflow:hidden;width:100%;height:520px;min-width:280px;min-height:180px;padding:0 0 12px 0;box-sizing:border-box;border:1px solid #8884;border-radius:4px;"><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
# &lt;meta charset=&quot;utf-8&quot;&gt;
# &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1&quot;&gt;
# &lt;title&gt;QuatPlot&lt;/title&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/ganja.js&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
#   :root{
#     --bg:#f5f6f8; --panel:#ffffff; --ink:#1c2430; --muted:#68737f;
#     --edge:#d8dde3; --accent:#2563b0; --grid:#c9cfd6; --cube:#b6bdc6;
#     --tip-bg:#1c2430; --tip-ink:#f5f6f8;
#   }
#   [data-theme=&quot;dark&quot;]{
#     --bg:#14181d; --panel:#1d232a; --ink:#e8ecf1; --muted:#93a0ad;
#     --edge:#313a44; --accent:#5aa2e8; --grid:#3a444f; --cube:#4a5560;
#     --tip-bg:#e8ecf1; --tip-ink:#14181d;
#   }
# ...

# %% [markdown]
# ## Combined: surface + scatter
# Multiple traces overlay in one plot; axes autoscale to the union of all data.

# %%
sx = rng.uniform(-3, 3, 60)
sy = rng.uniform(-3, 3, 60)
sz = (3*(1 - sx)**2 * np.exp(-sx**2 - (sy + 1)**2)
      - 10*(sx/5 - sx**3 - sy**5) * np.exp(-sx**2 - sy**2)
      - 1/3 * np.exp(-(sx + 1)**2 - sy**2)) + 1.5   # samples floating above the surface

p = qp.plot(qp.Surface(x, y, Z), qp.Scatter3(sx, sy, sz), theme='light', height=520)
p
# Out:
# <div style="resize:both;overflow:hidden;width:100%;height:520px;min-width:280px;min-height:180px;padding:0 0 12px 0;box-sizing:border-box;border:1px solid #8884;border-radius:4px;"><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
# &lt;meta charset=&quot;utf-8&quot;&gt;
# &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1&quot;&gt;
# &lt;title&gt;QuatPlot&lt;/title&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/ganja.js&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
#   :root{
#     --bg:#f5f6f8; --panel:#ffffff; --ink:#1c2430; --muted:#68737f;
#     --edge:#d8dde3; --accent:#2563b0; --grid:#c9cfd6; --cube:#b6bdc6;
#     --tip-bg:#1c2430; --tip-ink:#f5f6f8;
#   }
#   [data-theme=&quot;dark&quot;]{
#     --bg:#14181d; --panel:#1d232a; --ink:#e8ecf1; --muted:#93a0ad;
#     --edge:#313a44; --accent:#5aa2e8; --grid:#3a444f; --cube:#4a5560;
#     --tip-bg:#e8ecf1; --tip-ink:#14181d;
#   }
# ...

# %% [markdown]
# ## Standalone HTML export
# `qp.save` writes a self-contained file — same template, and the Screenshot button downloads directly there.

# %%
qp.save('peaks.html', qp.Surface(x, y, Z), cmap='Coolwarm')
# Out:
# 'peaks.html'

# %% [markdown]
# ## WandB logging

# %%
#!uv pip install wandb

# %%
import wandb
wandb.login()
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /Users/shawley/.netrc.
# wandb: Currently logged in as: drscotthawley to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
run = wandb.init(project="quatplot-demo")
run.log({"surface_plot": wandb.Html(p.html)})
run.finish()
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">floral-wind-4</strong> at: <a href='https://wandb.ai/drscotthawley/quatplot-demo/runs/68ge9ruh' target="_blank">https://wandb.ai/drscotthawley/quatplot-demo/runs/68ge9ruh</a><br> View project at: <a href='https://wandb.ai/drscotthawley/quatplot-demo' target="_blank">https://wandb.ai/drscotthawley/quatplot-demo</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260721_183047-68ge9ruh/logs</code>
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/Users/shawley/github/quatplot/examples/wandb/run-20260721_183100-e8j905ql</code>
# ...
